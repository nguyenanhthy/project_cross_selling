# %%
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import *
from delta import *
from pyspark.sql.types import IntegerType, StructType, StructField
from pyspark.sql.types import TimestampType
from pyspark.sql.window import Window


builder = SparkSession.builder.appName("OlistSilverTransformation") \
    .config("spark.sql.extensions", "io.delta.sql.DeltaSparkSessionExtension") \
    .config("spark.sql.catalog.spark_catalog", "org.apache.spark.sql.delta.catalog.DeltaCatalog")

spark = configure_spark_with_delta_pip(builder).getOrCreate()

# Đường dẫn các tầng
bronze_root = "/home/jovyan/work/delta_lake/bronze"
silver_root = "/home/jovyan/work/delta_lake/silver"
checkpoint_silver = "/home/jovyan/work/delta_lake/_checkpoints/silver"

# %% [markdown]
# ### BẢNG PRODUCTS
# Từ bước khám phá dữ liệu, ta có các công việc cần làm tại tầng silver như sau:
# - 610 dòng null -> làm sạch null
# - Dịch tên category thêm vào 2 category chưa có bản dịch tên tiếng anh

# %% [markdown]
# BATCH
# - Giải thích mục đích batch: nói rõ rằng batch chỉ dùng để bootstrap bảng Silver ban đầu, tạo folder và dữ liệu khởi tạo để các bảng khác (như order_items) có thể join. Đây là bước khởi tạo cần thiết vì streaming không tạo folder nếu chưa có dữ liệu.

# %%
# Đọc Bronze
df_products_bronze_batch = spark.read.format("delta").load(f"{bronze_root}/products")
df_translations = spark.read.format("delta").load(f"{bronze_root}/translations")

# Khai báo schema giống với df_translations
schema = StructType([
    StructField("product_category_name", StringType(), True),
    StructField("product_category_name_english", StringType(), True),
    StructField("ingested_at", TimestampType(), True),
    StructField("source_file", StringType(), True)
])

# Tạo dữ liệu bổ sung với đủ 4 cột
extra_mapping = [
    ("pc_gamer", "pc_gamer", None, "manual_addition"),
    ("portateis_cozinha_e_preparadores_de_alimentos", "kitchen_portables", None, "manual_addition")
]

df_extra = spark.createDataFrame(extra_mapping, schema)

# Union sẽ hợp lệ vì cùng số cột và kiểu dữ liệu
df_translation_fixed = df_translations.union(df_extra)


# Loại bỏ null category
df_clean = df_products_bronze_batch.filter(F.col("product_category_name").isNotNull())

# Join với translation để lấy tên tiếng Anh
df_joined = df_clean.join(df_translation_fixed, on="product_category_name", how="left")

# Loại bỏ các cột kỹ thuật không cần thiết
df_joined = df_joined.drop("ingested_at", "source_file")

# Ép kiểu các cột số
df_casted = df_joined \
    .withColumn("product_photos_qty", F.col("product_photos_qty").cast(IntegerType())) \
    .withColumn("product_weight_g", F.col("product_weight_g").cast(IntegerType())) \
    .withColumn("product_length_cm", F.col("product_length_cm").cast(IntegerType())) \
    .withColumn("product_height_cm", F.col("product_height_cm").cast(IntegerType())) \
    .withColumn("product_width_cm", F.col("product_width_cm").cast(IntegerType()))

# Loại trùng lặp theo product_id
df_products_silver_batch = df_casted.dropDuplicates(["product_id"])

# Ghi xuống Silver
df_products_silver_batch.write.format("delta").mode("overwrite").save(f"{silver_root}/products")

# %% [markdown]
# STREAMING
# - Giải thích mục đích streaming: sau khi đã có folder, chuyển sang readStream + writeStream để pipeline tiếp tục ingest dữ liệu mới theo thời gian thực. Như vậy vẫn giữ được tính streaming của Lakehouse.

# %%
# Đọc Bronze
df_products_bronze = spark.readStream.format("delta").load(f"{bronze_root}/products")
df_translations = spark.read.format("delta").load(f"{bronze_root}/translations")

# Khai báo schema giống với df_translations
schema = StructType([
    StructField("product_category_name", StringType(), True),
    StructField("product_category_name_english", StringType(), True),
    StructField("ingested_at", TimestampType(), True),
    StructField("source_file", StringType(), True)
])

# Tạo dữ liệu bổ sung với đủ 4 cột
extra_mapping = [
    ("pc_gamer", "pc_gamer", None, "manual_addition"),
    ("portateis_cozinha_e_preparadores_de_alimentos", "kitchen_portables", None, "manual_addition")
]

df_extra = spark.createDataFrame(extra_mapping, schema)

# Union sẽ hợp lệ vì cùng số cột và kiểu dữ liệu
df_translation_fixed = df_translations.union(df_extra)


# Loại bỏ null category
df_clean = df_products_bronze.filter(F.col("product_category_name").isNotNull())

# Join với translation để lấy tên tiếng Anh
df_joined = df_clean.join(df_translation_fixed, on="product_category_name", how="left")

# Ép kiểu các cột số
df_casted = df_joined \
    .withColumn("product_photos_qty", F.col("product_photos_qty").cast(IntegerType())) \
    .withColumn("product_weight_g", F.col("product_weight_g").cast(IntegerType())) \
    .withColumn("product_length_cm", F.col("product_length_cm").cast(IntegerType())) \
    .withColumn("product_height_cm", F.col("product_height_cm").cast(IntegerType())) \
    .withColumn("product_width_cm", F.col("product_width_cm").cast(IntegerType()))

# Loại trùng lặp theo product_id
df_products_silver = df_casted.dropDuplicates(["product_id"])

# Ghi xuống Silver
query_products = df_products_silver.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/products") \
    .start(f"{silver_root}/products")

# Kiểm tra query đang chạy
spark.streams.active

# %% [markdown]
# ### BẢNG CUSTOMERS

# %%
# Đọc Bronze
df_customers_bronze = spark.readStream.format("delta").load(f"{bronze_root}/customers")

# 1. Loại bỏ null (phòng ngừa, dù hiện tại không có)
df_clean = df_customers_bronze.filter(
    F.col("customer_id").isNotNull() & F.col("customer_unique_id").isNotNull()
)

# 2. Loại bỏ trùng lặp theo customer_id
df_dedup = df_clean.dropDuplicates(["customer_id"])

# 3. Ghi xuống Silver
query_customers = df_dedup.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/customers") \
    .start(f"{silver_root}/customers")

# %% [markdown]
# ### BẢNG ORDERS

# %%
# Đọc Bronze
df_orders_bronze = spark.readStream.format("delta").load(f"{bronze_root}/orders")

# 1. Lọc trạng thái đơn hàng
df_filtered = df_orders_bronze.filter(F.col("order_status") == "delivered")

# 2. Loại bỏ null order_id
df_clean = df_filtered.filter(F.col("order_id").isNotNull())

# 3. Ép kiểu thời gian
df_casted = df_clean \
    .withColumn("order_purchase_timestamp", F.col("order_purchase_timestamp").cast(TimestampType())) \
    .withColumn("order_approved_at", F.col("order_approved_at").cast(TimestampType())) \
    .withColumn("order_delivered_customer_date", F.col("order_delivered_customer_date").cast(TimestampType()))

# 4. Loại bỏ đơn hàng không hợp lệ
df_valid = df_casted.filter(
    (F.col("order_delivered_customer_date").isNotNull()) &
    (F.col("order_approved_at").isNotNull()) &
    (F.col("order_delivered_customer_date") >= F.col("order_purchase_timestamp"))
)

# 5. Loại trùng lặp theo order_id (phòng ngừa)
df_orders_silver = df_valid.dropDuplicates(["order_id"])

# 6. Ghi xuống Silver
query_orders = df_orders_silver.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/orders") \
    .start(f"{silver_root}/orders")

# %% [markdown]
# ### BẢNG ORDER_ITEMS

# %%
# Đọc Bronze
df_order_items_bronze = spark.readStream.format("delta").load(f"{bronze_root}/order_items")
df_products_silver = spark.read.format("delta").load(f"{silver_root}/products")

# 1. Loại bỏ null và sản phẩm không tồn tại
df_clean = df_order_items_bronze.filter(
    F.col("order_id").isNotNull() & F.col("product_id").isNotNull()
)

# Inner join với products Silver để đảm bảo product_id hợp lệ
df_valid = df_clean.join(df_products_silver.select("product_id"), on="product_id", how="inner")

# 2. Tính total_item_price
df_with_price = df_valid.withColumn("total_item_price", F.col("price") + F.col("freight_value"))

# 3. Thêm cột items_per_order
items_count = df_with_price.groupBy("order_id").agg(F.count("*").alias("items_per_order"))
df_final = df_with_price.join(items_count, on="order_id", how="left")

# 4. (Enrichment để sau, không làm ở đây)

# Loại trùng lặp phòng ngừa
df_order_items_silver = df_final.dropDuplicates(["order_id", "product_id"])

# Ghi xuống Silver
query_order_items = df_order_items_silver.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/order_items") \
    .start(f"{silver_root}/order_items")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In [12], line 30
#      23 df_order_items_silver = df_final.dropDuplicates(["order_id", "product_id"])
#      25 # Ghi xuống Silver
#      26 query_order_items = df_order_items_silver.writeStream \
#      27     .format("delta") \
#      28     .outputMode("append") \
#      29     .option("checkpointLocation", f"{checkpoint_silver}/order_items") \
# ---> 30     .start(f"{silver_root}/order_items")
#
# File /usr/local/spark/python/pyspark/sql/streaming.py:1391, in DataStreamWriter.start(self, path, format, outputMode, partitionBy, queryName, **options)
#    1389     return self._sq(self._jwrite.start())
#    1390 else:
# -> 1391     return self._sq(self._jwrite.start(path))
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /usr/local/spark/python/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: Append output mode not supported when there are streaming aggregations on streaming DataFrames/DataSets without watermark;
# Deduplicate [order_id#6971, product_id#6973]
# +- Project [order_id#6971, product_id#6973, order_item_id#6972, seller_id#6974, shipping_limit_date#6975, price#6976, freight_value#6977, ingested_at#6978, source_file#6979, total_item_price#7020, items_per_order#7042L]
#    +- Join LeftOuter, (order_id#6971 = order_id#7045)
#       :- Project [product_id#6973, order_id#6971, order_item_id#6972, seller_id#6974, shipping_limit_date#6975, price#6976, freight_value#6977, ingested_at#6978, source_file#6979, (price#6976 + freight_value#6977) AS total_item_price#7020]
#       :  +- Project [product_id#6973, order_id#6971, order_item_id#6972, seller_id#6974, shipping_limit_date#6975, price#6976, freight_value#6977, ingested_at#6978, source_file#6979]
#       :     +- Join Inner, (product_id#6973 = product_id#6990)
#       :        :- Filter (isnotnull(order_id#6971) AND isnotnull(product_id#6973))
#       :        :  +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@103ee184,delta,List(),None,List(),None,Map(path -> /home/jovyan/work/delta_lake/bronze/order_items),None), delta, [order_id#6971, order_item_id#6972, product_id#6973, seller_id#6974, shipping_limit_date#6975, price#6976, freight_value#6977, ingested_at#6978, source_file#6979]
#       :        +- Project [product_id#6990]
#       :           +- Relation [product_category_name#6989,product_id#6990,product_name_lenght#6991,product_description_lenght#6992,product_photos_qty#6993,product_weight_g#6994,product_length_cm#6995,product_height_cm#6996,product_width_cm#6997,product_category_name_english#6998] parquet
#       +- Aggregate [order_id#7045], [order_id#7045, count(1) AS items_per_order#7042L]
#          +- Project [product_id#7047, order_id#7045, order_item_id#7046, seller_id#7048, shipping_limit_date#7049, price#7050, freight_value#7051, ingested_at#7052, source_file#7053, (price#7050 + freight_value#7051) AS total_item_price#7020]
#             +- Project [product_id#7047, order_id#7045, order_item_id#7046, seller_id#7048, shipping_limit_date#7049, price#7050, freight_value#7051, ingested_at#7052, source_file#7053]
#                +- Join Inner, (product_id#7047 = product_id#6990)
#                   :- Filter (isnotnull(order_id#7045) AND isnotnull(product_id#7047))
#                   :  +- StreamingRelation DataSource(org.apache.spark.sql.SparkSession@103ee184,delta,List(),None,List(),None,Map(path -> /home/jovyan/work/delta_lake/bronze/order_items),None), delta, [order_id#7045, order_item_id#7046, product_id#7047, seller_id#7048, shipping_limit_date#7049, price#7050, freight_value#7051, ingested_at#7052, source_file#7053]
#                   +- Project [product_id#6990]
#                      +- Relation [product_category_name#6989,product_id#6990,product_name_lenght#6991,product_description_lenght#6992,product_photos_qty#6993,product_weight_g#6994,product_length_cm#6995,product_height_cm#6996,product_width_cm#6997,product_category_name_english#6998] parquet

# %%
# Đăng ký bảng Silver order_items vào catalog tạm
spark.sql(f"CREATE TABLE IF NOT EXISTS order_items_silver USING DELTA LOCATION '{silver_root}/order_items'")

# Chạy truy vấn SQL để tính items_per_order
result = spark.sql("""
    SELECT order_id, COUNT(*) AS items_per_order
    FROM order_items_silver
    GROUP BY order_id
""")

# Xem kết quả
result.show()
# Out:
# +--------------------+---------------+
# |            order_id|items_per_order|
# +--------------------+---------------+
# |014405982914c2cde...|              2|
# |019886de8f385a39b...|              1|
# |01a6ad782455876aa...|              1|
# |01d907b3e209269e1...|              1|
# |028dc52e12ddda803...|              1|
# |036dd381dfb3ec75e...|              1|
# |03ebfa9712b7dbc70...|              1|
# |0420da8d50a378401...|              1|
# |05afef1c185862cab...|              2|
# |05bef443b85068505...|              1|
# |05d46826bd0fb605d...|              1|
# |06fec3f6e9e72edb6...|              1|
# |077700dcf4e3bb412...|              1|
# |078c2d9bb7e5905e8...|              2|
# |08791ec24b12af5af...|              1|
# |08b450b388221bfe5...|              1|
# |0957ed870116e596b...|              1|
# |09868b0eb512bfbbe...|              1|
# |099d60cb800db65a7...|              1|
# |09e90e3936db197d4...|              1|
# +--------------------+---------------+
# only showing top 20 rows

# %% [markdown]
# ### BẢNG PRODUCTS
# - Thêm cột product_name

# %%
# Đọc lại products_base (Silver cơ bản) và order_items_silver
df_products_base = spark.read.format("delta").load(f"{silver_root}/products")
df_order_items_silver = spark.read.format("delta").load(f"{silver_root}/order_items")

# 1. Tính số đơn hàng mỗi sản phẩm
prod_counts = df_order_items_silver.groupBy("product_id") \
    .agg(F.countDistinct("order_id").alias("order_count"))

# 2. Join với products_base để bổ sung order_count
df_with_counts = df_products_base.join(prod_counts, on="product_id", how="left")

# 3. Rank theo order_count trong từng category
window_spec = Window.partitionBy("product_category_name_english").orderBy(F.col("order_count").desc())
df_ranked = df_with_counts.withColumn("rank_in_category", F.row_number().over(window_spec))

# 4. Tạo product_name theo công thức
df_final = df_ranked.withColumn(
    "product_name",
    F.concat_ws("-", F.col("product_category_name_english"), F.col("rank_in_category"))
)

# 5. Ép kiểu và loại trùng
df_products_silver = df_final.withColumn("product_photos_qty", F.col("product_photos_qty").cast(IntegerType())) \
                             .dropDuplicates(["product_id"])

# 6. Ghi xuống Silver (ghi đè hoặc append tuỳ bạn muốn)
query_products = df_products_silver.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/products_enriched") \
    .start(f"{silver_root}/products")
# Out:
# ---------------------------------------------------------------------------
# AnalysisException                         Traceback (most recent call last)
# Cell In [52], line 27
#      23 df_products_silver = df_final.withColumn("product_photos_qty", F.col("product_photos_qty").cast(IntegerType())) \
#      24                              .dropDuplicates(["product_id"])
#      26 # 6. Ghi xuống Silver (ghi đè hoặc append tuỳ bạn muốn)
# ---> 27 query_products = df_products_silver.writeStream \
#      28     .format("delta") \
#      29     .outputMode("append") \
#      30     .option("checkpointLocation", f"{checkpoint_silver}/products_enriched") \
#      31     .start(f"{silver_root}/products")
#
# File /usr/local/spark/python/pyspark/sql/dataframe.py:356, in DataFrame.writeStream(self)
#     340 @property
#     341 def writeStream(self) -> DataStreamWriter:
#     342     """
#     343     Interface for saving the content of the streaming :class:`DataFrame` out into external
#     344     storage.
#    (...)
#     354     :class:`DataStreamWriter`
#     355     """
# --> 356     return DataStreamWriter(self)
#
# File /usr/local/spark/python/pyspark/sql/streaming.py:860, in DataStreamWriter.__init__(self, df)
#     858 self._df = df
#     859 self._spark = df.sparkSession
# --> 860 self._jwrite = df._jdf.writeStream()
#
# File /usr/local/spark/python/lib/py4j-0.10.9.5-src.zip/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1315 command = proto.CALL_COMMAND_NAME +\
#    1316     self.command_header +\
#    1317     args_command +\
#    1318     proto.END_COMMAND_PART
#    1320 answer = self.gateway_client.send_command(command)
# -> 1321 return_value = get_return_value(
#    1322     answer, self.gateway_client, self.target_id, self.name)
#    1324 for temp_arg in temp_args:
#    1325     temp_arg._detach()
#
# File /usr/local/spark/python/pyspark/sql/utils.py:196, in capture_sql_exception.<locals>.deco(*a, **kw)
#     192 converted = convert_exception(e.java_exception)
#     193 if not isinstance(converted, UnknownException):
#     194     # Hide where the exception came from that shows a non-Pythonic
#     195     # JVM exception message.
# --> 196     raise converted from None
#     197 else:
#     198     raise
#
# AnalysisException: 'writeStream' can be called only on streaming Dataset/DataFrame

# %%
# Đọc Silver tables
df_orders_silver = spark.read.format("delta").load(f"{silver_root}/orders")
df_customers_silver = spark.read.format("delta").load(f"{silver_root}/customers")
df_order_items_silver = spark.read.format("delta").load(f"{silver_root}/order_items")
df_products_silver = spark.read.format("delta").load(f"{silver_root}/products")

# 1. Join orders + customers
df_orders_customers = df_orders_silver.join(
    df_customers_silver.select("customer_id", "customer_state"),
    on="customer_id",
    how="inner"
)

# 2. Join với order_items
df_orders_items = df_orders_customers.join(
    df_order_items_silver,
    on="order_id",
    how="inner"
)

# 3. Join với products
df_full = df_orders_items.join(
    df_products_silver.select("product_id", "product_name", "product_category_name_english"),
    on="product_id",
    how="inner"
)

# 4. Dataset tổng hợp
df_fact_silver = df_full.select(
    "order_id",
    "order_purchase_timestamp",
    "customer_id",
    "customer_state",
    "product_id",
    "product_name",
    "product_category_name_english",
    "price",
    "freight_value",
    "total_item_price",
    "items_per_order"
)

# 5. Ghi xuống Gold
query_fact = df_fact_silver.writeStream \
    .format("delta") \
    .outputMode("append") \
    .option("checkpointLocation", f"{checkpoint_silver}/gold_dataset") \
    .start(f"{silver_root}/gold_dataset")
# Out:
# notebook controller is DISPOSED.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
